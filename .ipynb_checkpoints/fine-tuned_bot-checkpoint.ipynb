# %%
pip install pandas datasets unsloth torch transformers requests
# Out:
# ...
#   Using cached datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached unsloth-2025.3.19-py3-none-any.whl.metadata (46 kB)
# ...
#   Using cached torch-2.6.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached transformers-4.50.2-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached pyarrow-19.0.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# ...
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached unsloth_zoo-2025.3.17-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached xformers-0.0.29.post3-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# ...
#   Using cached bitsandbytes-0.45.4-py3-none-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached triton_windows-3.2.0.post17-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# ...
#   Using cached tyro-0.9.17-py3-none-any.whl.metadata (9.5 kB)
# ...
